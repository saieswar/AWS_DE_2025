# %%
import pandas as pd

# %%
a  = pd.Series([1, 2, 3, 4, 5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a[3]
# Out:
# 4

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data, columns=['Name','Age'])

# %%
df
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
a  = {'age': [10,20,30], 'gender': ['m', 'f', 'm']}
b = pd.DataFrame(a)
b
# Out:
#    age gender
# 0   10      m
# 1   20      f
# 2   30      m

# %%
b['age']
# Out:
# 0    10
# 1    20
# 2    30
# Name: age, dtype: int64

# %%
b[b['age'] >10]
# Out:
#    age gender
# 1   20      f
# 2   30      m

# %%
b[b['age']>10]
# Out:
#    age gender
# 1   20      f
# 2   30      m

# %%
a = {'age': [25,27,35,29],
     'job': ['yes', 'no', 'yes', 'yes'],
     'Location':['hyd', 'hyd', 'chennai', 'Banglore'],
     'Salary': [1000,2000,4000, 900],
     'edu': ['B-Tech', 'Mtech', 'Masters', 'Intermediate']
     }

# %%
df = pd.DataFrame(a)
df
# Out:
#    age  job  Location  Salary           edu
# 0   25  yes       hyd    1000        B-Tech
# 1   27   no       hyd    2000         Mtech
# 2   35  yes   chennai    4000       Masters
# 3   29  yes  Banglore     900  Intermediate

# %%
df.loc[2,'Location']
# Out:
# 'chennai'

# %%
#[RowStart:RowEnd, ColumnStart:ColumnEnd]
df.loc[1:2, 'job':'Salary']
# Out:
#    job Location  Salary
# 1   no      hyd    2000
# 2  yes  chennai    4000

# %%
df.iloc[2,3]
# Out:
# 4000

# %%
data2=[["sunny",26],["manish",28],["priya",23]]
df2 = pd.DataFrame(data2, columns=['Name', 'Age'] ,index=['first', 'second', 'thrid'])
df2
# Out:
#           Name  Age
# first    sunny   26
# second  manish   28
# thrid    priya   23

# %%
df2.iloc[0,0]
# Out:
# 'sunny'

# %%
a = {'age': [25,27,35,29],
     'job': ['yes', 'no', 'yes', 'yes'],
     'Location':['hyd', 'hyd', 'chennai', 'Banglore'],
     'Salary': [1000,2000,4000, 900],
     'edu': ['B-Tech', 'Mtech', 'Masters', 'Intermediate']
     }

# %%
df = pd.DataFrame(a)
df
# Out:
#    age  job  Location  Salary           edu
# 0   25  yes       hyd    1000        B-Tech
# 1   27   no       hyd    2000         Mtech
# 2   35  yes   chennai    4000       Masters
# 3   29  yes  Banglore     900  Intermediate

# %%
df[ (df['age']>28) & (df['job']=='yes')  ]
# Out:
#    age  job  Location  Salary           edu
# 2   35  yes   chennai    4000       Masters
# 3   29  yes  Banglore     900  Intermediate

# %%
columns = ['order_id', 'order_date','order_customer_id', 'order_status']
orders  = pd.read_csv("orders.txt", header=None, names=columns)

# %%
df
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
pd.read_csv("orders_head.csv")
# Out:
#        Unnamed: 0  order_id             order_date  order_customer_id  \
# 0               0         1  2013-07-25 00:00:00.0              11599
# 1               1         2  2013-07-25 00:00:00.0                256
# 2               2         3  2013-07-25 00:00:00.0              12111
# 3               3         4  2013-07-25 00:00:00.0               8827
# 4               4         5  2013-07-25 00:00:00.0              11318
# ...           ...       ...                    ...                ...
# 68878       68878     68879  2014-07-09 00:00:00.0                778
# 68879       68879     68880  2014-07-13 00:00:00.0               1117
# 68880       68880     68881  2014-07-19 00:00:00.0               2518
# 68881       68881     68882  2014-07-22 00:00:00.0              10000
# 68882       68882     68883  2014-07-23 00:00:00.0               5533
#
#           order_status
# 0               CLOSED
# 1      PENDING_PAYMENT
# 2             COMPLETE
# 3               CLOSED
# ...

# %%
orders.head()
# Out:
#    order_id             order_date  order_customer_id     order_status
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE

# %%
orders.shape
# Out:
# (68883, 4)

# %%
orders[(orders['order_status']=='PENDING_PAYMENT') & (orders['order_date'] == "2013-07-25 00:00:00.0") ]
# Out:
#        order_id             order_date  order_customer_id     order_status
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 8             9  2013-07-25 00:00:00.0               5657  PENDING_PAYMENT
# 9            10  2013-07-25 00:00:00.0               5648  PENDING_PAYMENT
# 12           13  2013-07-25 00:00:00.0               9149  PENDING_PAYMENT
# 15           16  2013-07-25 00:00:00.0               7276  PENDING_PAYMENT
# 18           19  2013-07-25 00:00:00.0               9488  PENDING_PAYMENT
# 22           23  2013-07-25 00:00:00.0               4367  PENDING_PAYMENT
# 26           27  2013-07-25 00:00:00.0               3241  PENDING_PAYMENT
# 29           30  2013-07-25 00:00:00.0              10039  PENDING_PAYMENT
# 32           33  2013-07-25 00:00:00.0               5793  PENDING_PAYMENT
# 39           40  2013-07-25 00:00:00.0              12092  PENDING_PAYMENT
# ...

# %%
orders.query('   order_status == "PENDING_PAYMENT" & order_date == "2013-07-25 00:00:00.0"     ')
# Out:
#        order_id             order_date  order_customer_id     order_status
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 8             9  2013-07-25 00:00:00.0               5657  PENDING_PAYMENT
# 9            10  2013-07-25 00:00:00.0               5648  PENDING_PAYMENT
# 12           13  2013-07-25 00:00:00.0               9149  PENDING_PAYMENT
# 15           16  2013-07-25 00:00:00.0               7276  PENDING_PAYMENT
# 18           19  2013-07-25 00:00:00.0               9488  PENDING_PAYMENT
# 22           23  2013-07-25 00:00:00.0               4367  PENDING_PAYMENT
# 26           27  2013-07-25 00:00:00.0               3241  PENDING_PAYMENT
# 29           30  2013-07-25 00:00:00.0              10039  PENDING_PAYMENT
# 32           33  2013-07-25 00:00:00.0               5793  PENDING_PAYMENT
# 39           40  2013-07-25 00:00:00.0              12092  PENDING_PAYMENT
# ...

# %%
orders.query('order_status == ["COMPLETE", "CLOSED"]')
# Out:
#        order_id             order_date  order_customer_id order_status
# 0             1  2013-07-25 00:00:00.0              11599       CLOSED
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827       CLOSED
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [30455 rows x 4 columns]

# %%
orders.columns
# Out:
# Index(['order_id', 'order_date', 'order_customer_id', 'order_status'], dtype='object')

# %%
orders['order_status'].value_counts()
# Out:
# COMPLETE           22899
# PENDING_PAYMENT    15030
# PROCESSING          8275
# PENDING             7610
# CLOSED              7556
# ON_HOLD             3798
# SUSPECTED_FRAUD     1558
# CANCELED            1428
# PAYMENT_REVIEW       729
# Name: order_status, dtype: int64

# %%
orders.groupby('order_status')['order_id'].agg(order_count='count')
# Out:
#                  order_count
# order_status
# CANCELED                1428
# CLOSED                  7556
# COMPLETE               22899
# ON_HOLD                 3798
# PAYMENT_REVIEW           729
# PENDING                 7610
# PENDING_PAYMENT        15030
# PROCESSING              8275
# SUSPECTED_FRAUD         1558

# %%
orders.head()
# Out:
#    order_id             order_date  order_customer_id     order_status
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE

# %%
orders['month'] = orders.apply(lambda order: order['order_date'].split('-')[1], axis=1)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#       month
# 0        07
# 1        07
# 2        07
# 3        07
# ...

# %%
orders['yr_month'] = orders.apply(lambda order: order['order_date'][:7], axis=1)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
#       month yr_month
# 0        07  2013-07
# 1        07  2013-07
# ...

# %%
month_agg = orders.groupby(['month', 'order_status'])['order_id'].agg(order_count='count')

# %%
month_agg.to_csv('month_agg.csv')

# %%
orders.sort_values('order_customer_id')
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 22944     22945  2013-12-13 00:00:00.0                  1         COMPLETE
# 67862     67863  2013-11-30 00:00:00.0                  2         COMPLETE
# 33864     33865  2014-02-18 00:00:00.0                  2         COMPLETE
# 15191     15192  2013-10-29 00:00:00.0                  2  PENDING_PAYMENT
# 57962     57963  2013-08-02 00:00:00.0                  2          ON_HOLD
# ...         ...                    ...                ...              ...
# 42914     42915  2014-04-16 00:00:00.0              12434         COMPLETE
# 13543     13544  2013-10-16 00:00:00.0              12434          PENDING
# 5302       5303  2013-08-26 00:00:00.0              12434          PENDING
# 41642     41643  2014-04-08 00:00:00.0              12435          PENDING
# 61628     61629  2013-12-21 00:00:00.0              12435         CANCELED
#
#       month yr_month
# 22944    12  2013-12
# 67862    11  2013-11
# ...
